# %% [markdown]
# <a href="https://colab.research.google.com/github/avancs/LogicMojo-AI-ML-April26-Srikaanth/blob/main/Pyramid%20Pattern.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
h = 5
for i in range(h):
  spaces = " " * (h - i -1)
  stars = "*" * (2 * i + 1)
  print(spaces + stars)
# Out:
#     *
#    ***
#   *****
#  *******
# *********
